# %%
#dependencies
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
#create random sets of lat+long combos
lats = np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats, lngs)

# %%
#add lats and lngs to a list
coordinates=list(lat_lngs)

# use citipy script (imported up top)
# create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url +"&q=" + city.replace(" ","+")
requests.get(city_url).json()
# Out:
# {'coord': {'lon': 10.7, 'lat': 46.62},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 48.2,
#   'feels_like': 43.23,
#   'temp_min': 48.2,
#   'temp_max': 48.2,
#   'pressure': 1023,
#   'humidity': 81},
#  'visibility': 10000,
#  'wind': {'speed': 5.82, 'deg': 20},
#  'clouds': {'all': 75},
#  'dt': 1604290614,
#  'sys': {'type': 1,
#   'id': 6813,
#   'country': 'IT',
#   'sunrise': 1604296850,
#   'sunset': 1604332835},
#  'timezone': 3600,
#  'id': 3175096,
#  'name': 'Laas',
#  'cod': 200}

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#create empty list to hold the weather data
city_data=[]

#print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

#creat counters
record_count=1
set_count=1

#loop through list of cities to build the city URLs
#using counters to keep track of both the list we're building and how many lists

for i, city in enumerate(cities):
    
    #group cities in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    #create endpoint URL with each city
    city_url = url +"&q=" + city.replace(" ","+")
    
    #log the url, record and set counters and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #add 1 to the record count
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdesc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weatherdesc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | erenhot
# Processing Record 2 of Set 1 | bo phloi
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | tabou
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | smithers
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | miamisburg
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | diego de almagro
# Processing Record 28 of Set 1 | sembakung
# Processing Record 29 of Set 1 | belmonte
# Processing Record 30 of Set 1 | khandyga
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | garwa
# Processing Record 33 of Set 1 | sorokino
# Processing Record 34 of Set 1 | atambua
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 1 | isla mujeres
# Processing Record 40 of Set 1 | guerrero negro
# Processing Record 41 of Set 1 | micasasa
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | ust-nera
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | tiznit
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | izhmorskiy
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | sao raimundo nonato
# Processing Record 3 of Set 2 | isangel
# Processing Record 4 of Set 2 | picos
# Processing Record 5 of Set 2 | zephyrhills
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | thinadhoo
# Processing Record 8 of Set 2 | ferrenafe
# Processing Record 9 of Set 2 | coquimbo
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | zhigansk
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | belaya gora
# Processing Record 19 of Set 2 | vardo
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | burhaniye
# Processing Record 23 of Set 2 | khani
# Processing Record 24 of Set 2 | luanda
# Processing Record 25 of Set 2 | rafsanjan
# Processing Record 26 of Set 2 | oksfjord
# Processing Record 27 of Set 2 | abu dhabi
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | novaya zaimka
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | meulaboh
# Processing Record 35 of Set 2 | tsiroanomandidy
# Processing Record 36 of Set 2 | krasnoselkup
# Processing Record 37 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 2 | esmeralda
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | katangli
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | progreso
# Processing Record 43 of Set 2 | antofagasta
# Processing Record 44 of Set 2 | havoysund
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | mathathane
# Processing Record 47 of Set 2 | seydi
# Processing Record 48 of Set 2 | adrar
# Processing Record 49 of Set 2 | half moon bay
# Processing Record 50 of Set 2 | patnos
# Processing Record 1 of Set 3 | camacha
# Processing Record 2 of Set 3 | evensk
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | yate
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | shu
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | kuusamo
# Processing Record 11 of Set 3 | cesis
# Processing Record 12 of Set 3 | codrington
# Processing Record 13 of Set 3 | bulembu
# Processing Record 14 of Set 3 | clarence town
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | yar-sale
# Processing Record 17 of Set 3 | akyab
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | coxim
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | lakes entrance
# Processing Record 24 of Set 3 | laguna
# Processing Record 25 of Set 3 | lokosovo
# Processing Record 26 of Set 3 | san quintin
# Processing Record 27 of Set 3 | westport
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | paso de los toros
# Processing Record 32 of Set 3 | sakakah
# Processing Record 33 of Set 3 | boa vista
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | cabo san lucas
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | darhan
# Processing Record 39 of Set 3 | erdaojiang
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | dakar
# Processing Record 42 of Set 3 | filadelfia
# Processing Record 43 of Set 3 | beloha
# Processing Record 44 of Set 3 | kavaratti
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | takoradi
# Processing Record 48 of Set 3 | korla
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | beterou
# Processing Record 1 of Set 4 | orikum
# Processing Record 2 of Set 4 | hirara
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | mancora
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 4 | odienne
# Processing Record 9 of Set 4 | bajil
# Processing Record 10 of Set 4 | flin flon
# Processing Record 11 of Set 4 | paamiut
# Processing Record 12 of Set 4 | barroualie
# City not found. Skipping...
# Processing Record 13 of Set 4 | zhanaozen
# Processing Record 14 of Set 4 | la rioja
# Processing Record 15 of Set 4 | mayo
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | koumac
# Processing Record 18 of Set 4 | geraldton
# Processing Record 19 of Set 4 | cayenne
# Processing Record 20 of Set 4 | kemin
# Processing Record 21 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 4 | luban
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | lufilufi
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | marzuq
# Processing Record 27 of Set 4 | buala
# Processing Record 28 of Set 4 | kokologo
# Processing Record 29 of Set 4 | sao miguel do araguaia
# Processing Record 30 of Set 4 | champerico
# Processing Record 31 of Set 4 | lubao
# Processing Record 32 of Set 4 | cairns
# Processing Record 33 of Set 4 | bethel
# Processing Record 34 of Set 4 | vila franca do campo
# Processing Record 35 of Set 4 | flinders
# Processing Record 36 of Set 4 | segezha
# Processing Record 37 of Set 4 | chumikan
# Processing Record 38 of Set 4 | sao joao da barra
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | praia
# Processing Record 41 of Set 4 | manihari
# Processing Record 42 of Set 4 | kars
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | ondo
# Processing Record 46 of Set 4 | marrakesh
# Processing Record 47 of Set 4 | canon city
# Processing Record 48 of Set 4 | soma
# Processing Record 49 of Set 4 | ixtapa
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | florianopolis
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | zapolyarnyy
# Processing Record 4 of Set 5 | chaihe
# Processing Record 5 of Set 5 | bintulu
# Processing Record 6 of Set 5 | teya
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | nantucket
# Processing Record 9 of Set 5 | leshukonskoye
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 5 | manoel urbano
# Processing Record 13 of Set 5 | zabol
# Processing Record 14 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 15 of Set 5 | zhuanghe
# Processing Record 16 of Set 5 | tumaco
# Processing Record 17 of Set 5 | palapye
# Processing Record 18 of Set 5 | verkhoturye
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | burns lake
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | shakhrinau
# City not found. Skipping...
# Processing Record 23 of Set 5 | benghazi
# Processing Record 24 of Set 5 | debre tabor
# Processing Record 25 of Set 5 | merauke
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | itarema
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | luohe
# Processing Record 30 of Set 5 | lelystad
# Processing Record 31 of Set 5 | mbandaka
# Processing Record 32 of Set 5 | vila
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | nizhnedevitsk
# Processing Record 35 of Set 5 | ghanzi
# Processing Record 36 of Set 5 | kedrovyy
# Processing Record 37 of Set 5 | opuwo
# Processing Record 38 of Set 5 | awbari
# Processing Record 39 of Set 5 | avera
# Processing Record 40 of Set 5 | ulladulla
# Processing Record 41 of Set 5 | white rock
# Processing Record 42 of Set 5 | xuddur
# Processing Record 43 of Set 5 | thai binh
# Processing Record 44 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 5 | cantavir
# Processing Record 47 of Set 5 | oriximina
# Processing Record 48 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 5 | tubmanburg
# Processing Record 1 of Set 6 | rijeka
# Processing Record 2 of Set 6 | murgud
# Processing Record 3 of Set 6 | sobolevo
# Processing Record 4 of Set 6 | paragominas
# Processing Record 5 of Set 6 | kjollefjord
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | strezhevoy
# Processing Record 8 of Set 6 | eching
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | atasu
# Processing Record 11 of Set 6 | kupang
# Processing Record 12 of Set 6 | walvis bay
# Processing Record 13 of Set 6 | stephenville
# Processing Record 14 of Set 6 | dalianwan
# Processing Record 15 of Set 6 | teixeira
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | oranjemund
# Processing Record 18 of Set 6 | araouane
# Processing Record 19 of Set 6 | gualeguaychu
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | arraial do cabo
# Processing Record 23 of Set 6 | zhoucheng
# Processing Record 24 of Set 6 | tibati
# Processing Record 25 of Set 6 | japura
# Processing Record 26 of Set 6 | providencia
# Processing Record 27 of Set 6 | sorong
# Processing Record 28 of Set 6 | portland
# Processing Record 29 of Set 6 | komsomolskiy
# Processing Record 30 of Set 6 | sao raimundo das mangabeiras
# Processing Record 31 of Set 6 | iquique
# Processing Record 32 of Set 6 | roquetas de mar
# Processing Record 33 of Set 6 | kanniyakumari
# Processing Record 34 of Set 6 | najran
# Processing Record 35 of Set 6 | inyonga
# Processing Record 36 of Set 6 | dwarka
# Processing Record 37 of Set 6 | crevedia
# Processing Record 38 of Set 6 | darnah
# Processing Record 39 of Set 6 | saskylakh
# Processing Record 40 of Set 6 | yarensk
# Processing Record 41 of Set 6 | fremont
# Processing Record 42 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 6 | kingaroy
# Processing Record 44 of Set 6 | vestmannaeyjar
# Processing Record 45 of Set 6 | yulara
# Processing Record 46 of Set 6 | tashtyp
# Processing Record 47 of Set 6 | taman
# Processing Record 48 of Set 6 | porbandar
# Processing Record 49 of Set 6 | torbay
# Processing Record 50 of Set 6 | xai-xai
# Processing Record 1 of Set 7 | dharchula
# Processing Record 2 of Set 7 | luwuk
# Processing Record 3 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 7 | nowy tomysl
# Processing Record 5 of Set 7 | moose factory
# Processing Record 6 of Set 7 | lake city
# Processing Record 7 of Set 7 | maningrida
# Processing Record 8 of Set 7 | altay
# Processing Record 9 of Set 7 | soyo
# Processing Record 10 of Set 7 | gambo
# Processing Record 11 of Set 7 | elbistan
# Processing Record 12 of Set 7 | marsala
# Processing Record 13 of Set 7 | burnie
# Processing Record 14 of Set 7 | aswan
# Processing Record 15 of Set 7 | sur
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | ypsonas
# Processing Record 18 of Set 7 | innisfail
# Processing Record 19 of Set 7 | capao da canoa
# Processing Record 20 of Set 7 | alyangula
# Processing Record 21 of Set 7 | yelizovo
# Processing Record 22 of Set 7 | san carlos
# Processing Record 23 of Set 7 | balikpapan
# Processing Record 24 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 7 | aktau
# Processing Record 26 of Set 7 | la ronge
# Processing Record 27 of Set 7 | dudinka
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | karratha
# Processing Record 31 of Set 7 | black river
# Processing Record 32 of Set 7 | singaraja
# Processing Record 33 of Set 7 | komsomolets
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | coahuayana
# Processing Record 36 of Set 7 | russell
# Processing Record 37 of Set 7 | hofn
# Processing Record 38 of Set 7 | chegdomyn
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | qesarya
# Processing Record 41 of Set 7 | raudeberg
# Processing Record 42 of Set 7 | naze
# Processing Record 43 of Set 7 | kalmunai
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | jurado
# Processing Record 46 of Set 7 | cervo
# Processing Record 47 of Set 7 | jintur
# Processing Record 48 of Set 7 | terney
# Processing Record 49 of Set 7 | necochea
# Processing Record 50 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 8 | labuhan
# Processing Record 2 of Set 8 | mitchell
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | los llanos de aridane
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | belyy yar
# Processing Record 7 of Set 8 | gari
# Processing Record 8 of Set 8 | mount gambier
# Processing Record 9 of Set 8 | acapulco
# Processing Record 10 of Set 8 | kuvshinovo
# Processing Record 11 of Set 8 | hualmay
# Processing Record 12 of Set 8 | axim
# Processing Record 13 of Set 8 | comodoro rivadavia
# Processing Record 14 of Set 8 | mokhsogollokh
# Processing Record 15 of Set 8 | vershino-darasunskiy
# Processing Record 16 of Set 8 | yarada
# Processing Record 17 of Set 8 | te anau
# Processing Record 18 of Set 8 | college
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | celestun
# Processing Record 21 of Set 8 | pittsburg
# Processing Record 22 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 8 | voiron
# Processing Record 24 of Set 8 | repalle
# Processing Record 25 of Set 8 | ilulissat
# Processing Record 26 of Set 8 | varhaug
# Processing Record 27 of Set 8 | nampula
# Processing Record 28 of Set 8 | bismarck
# Processing Record 29 of Set 8 | van
# Processing Record 30 of Set 8 | luderitz
# Processing Record 31 of Set 8 | vitimskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | cururupu
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | fez
# Processing Record 35 of Set 8 | den helder
# Processing Record 36 of Set 8 | jiuquan
# Processing Record 37 of Set 8 | bialogard
# Processing Record 38 of Set 8 | lata
# Processing Record 39 of Set 8 | norman wells
# Processing Record 40 of Set 8 | mega
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | rypin
# Processing Record 43 of Set 8 | veraval
# Processing Record 44 of Set 8 | atar
# Processing Record 45 of Set 8 | penzance
# Processing Record 46 of Set 8 | chau doc
# Processing Record 47 of Set 8 | onalaska
# Processing Record 48 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 8 | kamenka
# Processing Record 50 of Set 8 | temerloh
# Processing Record 1 of Set 9 | mount isa
# Processing Record 2 of Set 9 | saint george
# Processing Record 3 of Set 9 | makakilo city
# Processing Record 4 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 9 | luang prabang
# Processing Record 6 of Set 9 | yumen
# Processing Record 7 of Set 9 | reconquista
# Processing Record 8 of Set 9 | port shepstone
# Processing Record 9 of Set 9 | lazarev
# Processing Record 10 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 9 | pevek
# Processing Record 12 of Set 9 | vilcun
# Processing Record 13 of Set 9 | srednekolymsk
# Processing Record 14 of Set 9 | bogande
# Processing Record 15 of Set 9 | yaring
# Processing Record 16 of Set 9 | damavand
# Processing Record 17 of Set 9 | muroto
# Processing Record 18 of Set 9 | palm valley
# Processing Record 19 of Set 9 | kelvington
# Processing Record 20 of Set 9 | wajir
# Processing Record 21 of Set 9 | saposoa
# Processing Record 22 of Set 9 | churapcha
# Processing Record 23 of Set 9 | marsa matruh
# Processing Record 24 of Set 9 | olafsvik
# Processing Record 25 of Set 9 | kutum
# Processing Record 26 of Set 9 | iwaki
# Processing Record 27 of Set 9 | goderich
# Processing Record 28 of Set 9 | tilichiki
# Processing Record 29 of Set 9 | gimli
# Processing Record 30 of Set 9 | lasa
# Processing Record 31 of Set 9 | manyana
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 9 | masuguru
# Processing Record 36 of Set 9 | chekhov
# Processing Record 37 of Set 9 | novo aripuana
# Processing Record 38 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 9 | miyazu
# Processing Record 40 of Set 9 | kannur
# Processing Record 41 of Set 9 | noshiro
# Processing Record 42 of Set 9 | vila velha
# Processing Record 43 of Set 9 | tommot
# Processing Record 44 of Set 9 | batsfjord
# Processing Record 45 of Set 9 | skjervoy
# Processing Record 46 of Set 9 | yala
# Processing Record 47 of Set 9 | tezu
# Processing Record 48 of Set 9 | kastamonu
# Processing Record 49 of Set 9 | sioux lookout
# Processing Record 50 of Set 9 | mehamn
# Processing Record 1 of Set 10 | the valley
# Processing Record 2 of Set 10 | saldanha
# Processing Record 3 of Set 10 | talakan
# Processing Record 4 of Set 10 | juneau
# Processing Record 5 of Set 10 | cruzeiro do oeste
# Processing Record 6 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 10 | pitimbu
# Processing Record 8 of Set 10 | sao gabriel da cachoeira
# Processing Record 9 of Set 10 | odweyne
# Processing Record 10 of Set 10 | nelson bay
# Processing Record 11 of Set 10 | seminole
# Processing Record 12 of Set 10 | grand baie
# Processing Record 13 of Set 10 | xuanzhou
# Processing Record 14 of Set 10 | high rock
# Processing Record 15 of Set 10 | pokosnoye
# Processing Record 16 of Set 10 | salinopolis
# Processing Record 17 of Set 10 | baiyin
# Processing Record 18 of Set 10 | luganville
# Processing Record 19 of Set 10 | wukari
# Processing Record 20 of Set 10 | san rafael
# Processing Record 21 of Set 10 | victor harbor
# Processing Record 22 of Set 10 | lakeside
# Processing Record 23 of Set 10 | clyde river
# Processing Record 24 of Set 10 | yuci
# Processing Record 25 of Set 10 | anadyr
# Processing Record 26 of Set 10 | acari
# Processing Record 27 of Set 10 | charters towers
# Processing Record 28 of Set 10 | waipawa
# Processing Record 29 of Set 10 | noumea
# Processing Record 30 of Set 10 | sindor
# Processing Record 31 of Set 10 | yermakovskoye
# Processing Record 32 of Set 10 | derby
# Processing Record 33 of Set 10 | panguna
# Processing Record 34 of Set 10 | sohagpur
# Processing Record 35 of Set 10 | fairbanks
# Processing Record 36 of Set 10 | zambezi
# Processing Record 37 of Set 10 | sharlyk
# Processing Record 38 of Set 10 | daru
# Processing Record 39 of Set 10 | jhansi
# Processing Record 40 of Set 10 | tazovskiy
# Processing Record 41 of Set 10 | homer
# Processing Record 42 of Set 10 | zyryanovsk
# Processing Record 43 of Set 10 | koscian
# Processing Record 44 of Set 10 | lerwick
# Processing Record 45 of Set 10 | mengcheng
# Processing Record 46 of Set 10 | lupiro
# Processing Record 47 of Set 10 | ugoofaaru
# Processing Record 48 of Set 10 | sosva
# Processing Record 49 of Set 10 | roswell
# Processing Record 50 of Set 10 | vanavara
# Processing Record 1 of Set 11 | biak
# Processing Record 2 of Set 11 | galveston
# Processing Record 3 of Set 11 | porto walter
# Processing Record 4 of Set 11 | saint-francois
# Processing Record 5 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 6 of Set 11 | bayan
# Processing Record 7 of Set 11 | voitsberg
# Processing Record 8 of Set 11 | jagdalpur
# Processing Record 9 of Set 11 | itoman
# Processing Record 10 of Set 11 | talcahuano
# Processing Record 11 of Set 11 | arbazh
# Processing Record 12 of Set 11 | san pedro
# Processing Record 13 of Set 11 | sing buri
# Processing Record 14 of Set 11 | lashio
# Processing Record 15 of Set 11 | mayor pablo lagerenza
# Processing Record 16 of Set 11 | springfield
# Processing Record 17 of Set 11 | souillac
# Processing Record 18 of Set 11 | hakkari
# Processing Record 19 of Set 11 | mildura
# Processing Record 20 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 11 | shiraz
# Processing Record 22 of Set 11 | anloga
# Processing Record 23 of Set 11 | coihaique
# Processing Record 24 of Set 11 | tual
# Processing Record 25 of Set 11 | bambous virieux
# Processing Record 26 of Set 11 | prince rupert
# Processing Record 27 of Set 11 | muskogee
# Processing Record 28 of Set 11 | fernandopolis
# Processing Record 29 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 11 | morococha
# Processing Record 31 of Set 11 | bozoum
# Processing Record 32 of Set 11 | mahibadhoo
# Processing Record 33 of Set 11 | talnakh
# Processing Record 34 of Set 11 | buta
# Processing Record 35 of Set 11 | ise
# Processing Record 36 of Set 11 | cam ranh
# Processing Record 37 of Set 11 | kaduna
# Processing Record 38 of Set 11 | copiapo
# Processing Record 39 of Set 11 | pasni
# Processing Record 40 of Set 11 | cuenca
# Processing Record 41 of Set 11 | bilma
# Processing Record 42 of Set 11 | kemi
# Processing Record 43 of Set 11 | ust-ordynskiy
# Processing Record 44 of Set 11 | dauriya
# Processing Record 45 of Set 11 | ramgarh
# Processing Record 46 of Set 11 | liverpool
# Processing Record 47 of Set 11 | vorsma
# Processing Record 48 of Set 11 | beringovskiy
# Processing Record 49 of Set 11 | halvad
# Processing Record 50 of Set 11 | barao de melgaco
# Processing Record 1 of Set 12 | methoni
# Processing Record 2 of Set 12 | gat
# Processing Record 3 of Set 12 | chiang klang
# Processing Record 4 of Set 12 | iracoubo
# Processing Record 5 of Set 12 | port lincoln
# Processing Record 6 of Set 12 | vetralla
# Processing Record 7 of Set 12 | jalu
# Processing Record 8 of Set 12 | tautira
# Processing Record 9 of Set 12 | teknaf
# Processing Record 10 of Set 12 | naryan-mar
# Processing Record 11 of Set 12 | morag
# Processing Record 12 of Set 12 | andenes
# Processing Record 13 of Set 12 | katsuura
# Processing Record 14 of Set 12 | mitsamiouli
# Processing Record 15 of Set 12 | rincon
# Processing Record 16 of Set 12 | hanting
# Processing Record 17 of Set 12 | san francisco menendez
# Processing Record 18 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 19 of Set 12 | dickinson
# Processing Record 20 of Set 12 | itatskiy
# Processing Record 21 of Set 12 | poykovskiy
# Processing Record 22 of Set 12 | gonzalez
# Processing Record 23 of Set 12 | port hawkesbury
# Processing Record 24 of Set 12 | nha trang
# Processing Record 25 of Set 12 | mukhen
# Processing Record 26 of Set 12 | chamonix-mont-blanc
# Processing Record 27 of Set 12 | bonavista
# Processing Record 28 of Set 12 | nemuro
# Processing Record 29 of Set 12 | berlevag
# Processing Record 30 of Set 12 | gamba
# Processing Record 31 of Set 12 | tshane
# Processing Record 32 of Set 12 | gavle
# Processing Record 33 of Set 12 | alofi
# Processing Record 34 of Set 12 | ilhabela
# Processing Record 35 of Set 12 | figeac
# Processing Record 36 of Set 12 | auki
# Processing Record 37 of Set 12 | seybaplaya
# Processing Record 38 of Set 12 | valdivia
# Processing Record 39 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 40 of Set 12 | yerbogachen
# Processing Record 41 of Set 12 | ereymentau
# Processing Record 42 of Set 12 | shache
# Processing Record 43 of Set 12 | genhe
# Processing Record 44 of Set 12 | saint-augustin
# Processing Record 45 of Set 12 | iquitos
# Processing Record 46 of Set 12 | sibolga
# Processing Record 47 of Set 12 | lyuban
# Processing Record 48 of Set 12 | rundu
# Processing Record 49 of Set 12 | bougouni
# Processing Record 50 of Set 12 | berbera
# Processing Record 1 of Set 13 | katangi
# Processing Record 2 of Set 13 | novikovo
# Processing Record 3 of Set 13 | tateyama
# Processing Record 4 of Set 13 | saint-pierre
# Processing Record 5 of Set 13 | hattiesburg
# Processing Record 6 of Set 13 | richards bay
# Processing Record 7 of Set 13 | boende
# Processing Record 8 of Set 13 | henties bay
# Processing Record 9 of Set 13 | fontem
# Processing Record 10 of Set 13 | fort saint james
# Processing Record 11 of Set 13 | lamu
# Processing Record 12 of Set 13 | sabha
# Processing Record 13 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 14 of Set 13 | swan river
# Processing Record 15 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | puerto escondido
# Processing Record 17 of Set 13 | marsta
# Processing Record 18 of Set 13 | beidao
# Processing Record 19 of Set 13 | havre-saint-pierre
# Processing Record 20 of Set 13 | huaral
# Processing Record 21 of Set 13 | arman
# Processing Record 22 of Set 13 | tigil
# Processing Record 23 of Set 13 | rocha
# Processing Record 24 of Set 13 | catuday
# Processing Record 25 of Set 13 | tulun
# Processing Record 26 of Set 13 | sisimiut
# Processing Record 27 of Set 13 | bud
# Processing Record 28 of Set 13 | avallon
# Processing Record 29 of Set 13 | eyl
# Processing Record 30 of Set 13 | dubrajpur
# Processing Record 31 of Set 13 | maniitsoq
# Processing Record 32 of Set 13 | kieta
# Processing Record 33 of Set 13 | mokrous
# Processing Record 34 of Set 13 | grand-lahou
# Processing Record 35 of Set 13 | sangerhausen
# Processing Record 36 of Set 13 | bambanglipuro
# Processing Record 37 of Set 13 | susehri
# Processing Record 38 of Set 13 | nanning
# Processing Record 39 of Set 13 | neyshabur
# Processing Record 40 of Set 13 | sibu
# Processing Record 41 of Set 13 | trinidad
# Processing Record 42 of Set 13 | verkhniye tatyshly
# Processing Record 43 of Set 13 | santiago del estero
# Processing Record 44 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 13 | svetlogorsk
# Processing Record 46 of Set 13 | diffa
# Processing Record 47 of Set 13 | shenjiamen
# Processing Record 48 of Set 13 | iaciara
# Processing Record 49 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 13 | siretel
# Processing Record 1 of Set 14 | kirakira
# Processing Record 2 of Set 14 | benavente
# Processing Record 3 of Set 14 | rio gallegos
# Processing Record 4 of Set 14 | riberalta
# Processing Record 5 of Set 14 | sovetskiy
# Processing Record 6 of Set 14 | goroka
# Processing Record 7 of Set 14 | sabang
# Processing Record 8 of Set 14 | nzerekore
# Processing Record 9 of Set 14 | inhambane
# Processing Record 10 of Set 14 | mantua
# Processing Record 11 of Set 14 | pacific grove
# Processing Record 12 of Set 14 | stromness
# Processing Record 13 of Set 14 | chicama
# Processing Record 14 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 14 | poum
# Processing Record 16 of Set 14 | taoudenni
# Processing Record 17 of Set 14 | blagoyevo
# Processing Record 18 of Set 14 | tokur
# Processing Record 19 of Set 14 | turukhansk
# Processing Record 20 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 14 | chibuto
# Processing Record 22 of Set 14 | yeppoon
# Processing Record 23 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 14 | bolshaya atnya
# City not found. Skipping...
# Processing Record 25 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 14 | rio grande
# Processing Record 27 of Set 14 | slave lake
# Processing Record 28 of Set 14 | jhabua
# Processing Record 29 of Set 14 | helena
# Processing Record 30 of Set 14 | alugan
# Processing Record 31 of Set 14 | nyurba
# Processing Record 32 of Set 14 | alto araguaia
# Processing Record 33 of Set 14 | kachug
# Processing Record 34 of Set 14 | gemena
# Processing Record 35 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 36 of Set 14 | tura
# Processing Record 37 of Set 14 | nanakuli
# Processing Record 38 of Set 14 | washougal
# Processing Record 39 of Set 14 | pemba
# Processing Record 40 of Set 14 | peace river
# Processing Record 41 of Set 14 | carlisle
# Processing Record 42 of Set 14 | huaidian
# Processing Record 43 of Set 14 | omsukchan
# Processing Record 44 of Set 14 | brae
# Processing Record 45 of Set 14 | channel-port aux basques
# Processing Record 46 of Set 14 | druzhba
# Processing Record 47 of Set 14 | ngunguru
# Processing Record 48 of Set 14 | manadhoo
# Processing Record 49 of Set 14 | rawson
# Processing Record 50 of Set 14 | ende
# Processing Record 1 of Set 15 | colac
# Processing Record 2 of Set 15 | san jeronimo
# Processing Record 3 of Set 15 | martin
# Processing Record 4 of Set 15 | eureka
# Processing Record 5 of Set 15 | canutama
# Processing Record 6 of Set 15 | tahoua
# Processing Record 7 of Set 15 | soligalich
# Processing Record 8 of Set 15 | alenquer
# Processing Record 9 of Set 15 | okitipupa
# Processing Record 10 of Set 15 | san cristobal
# Processing Record 11 of Set 15 | harper
# Processing Record 12 of Set 15 | anta
# Processing Record 13 of Set 15 | olavarria
# Processing Record 14 of Set 15 | kitob
# Processing Record 15 of Set 15 | olenino
# Processing Record 16 of Set 15 | malaut
# Processing Record 17 of Set 15 | panjakent
# Processing Record 18 of Set 15 | staryy nadym
# Processing Record 19 of Set 15 | bordighera
# Processing Record 20 of Set 15 | tiarei
# Processing Record 21 of Set 15 | hayden
# Processing Record 22 of Set 15 | honningsvag
# Processing Record 23 of Set 15 | martinsville
# Processing Record 24 of Set 15 | san luis
# Processing Record 25 of Set 15 | husavik
# Processing Record 26 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 15 | houma
# Processing Record 28 of Set 15 | bubaque
# Processing Record 29 of Set 15 | belize
# Processing Record 30 of Set 15 | esil
# Processing Record 31 of Set 15 | ucluelet
# Processing Record 32 of Set 15 | dali
# Processing Record 33 of Set 15 | uchiza
# Processing Record 34 of Set 15 | cockburn town
# Processing Record 35 of Set 15 | kampot
# Processing Record 36 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 15 | zuwarah
# Processing Record 38 of Set 15 | nueva helvecia
# Processing Record 39 of Set 15 | carmen
# Processing Record 40 of Set 15 | cadereyta
# Processing Record 41 of Set 15 | paita
# Processing Record 42 of Set 15 | tripoli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Erenhot      CN  43.65  111.98     29.28        66           0
# 1      Bo Phloi      TH  14.32   99.52     84.25        73          23
# 2        Barrow      US  71.29 -156.79     26.60        68          75
# 3         Bluff      NZ -46.60  168.33     55.99        67          26
# 4      Hermanus      ZA -34.42   19.23     63.00        86          97
# 5    Georgetown      MY   5.41  100.34     86.00        74          20
# 6  Punta Arenas      CL -53.15  -70.92     51.80        71           0
# 7          Lebu      CL -37.62  -73.65     52.81        93          96
# 8      Bengkulu      ID  -3.80  102.27     83.41        70         100
# 9         Tabou      CI   4.42   -7.35     77.00        89          31
#
#    Wind Speed Weather Description
# 0       18.99           clear sky
# 1        9.37          few clouds
# 2       12.75       broken clouds
# 3       11.01    scattered clouds
# 4        1.99     overcast clouds
# 5        5.82          few clouds
# 6        5.82           clear sky
# 7        6.82     overcast clouds
# 8        1.95     overcast clouds
# 9        5.57    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
